# %%
import json
import matplotlib.pyplot as plt

# %%
try:
    arq = open("espectro.json","r")
    print("deu bom")
    j = arq.read()
except:
    print("deu ruim")
arq.close()
# Out:
# deu bom

# %%
dic = json.loads(j)
print(dic)
# Out:
# {'data': [{'line': {'color': '#fab763', 'width': 3}, 'meta': {'columnNames': {'x': 'lambda (nm)', 'y': 'Intensidade'}}, 'mode': 'lines', 'name': 'Na', 'type': 'scatter', 'xsrc': 'guswieder:7:7d56e6', 'x': ['339.05', '339.43', '339.81', '340.19', '340.57', '340.95', '341.33', '341.71', '342.09', '342.47', '342.85', '343.23', '343.61', '343.99', '344.37', '344.75', '345.12', '345.50', '345.88', '346.26', '346.64', '347.02', '347.40', '347.78', '348.16', '348.54', '348.92', '349.30', '349.67', '350.05', '350.43', '350.81', '351.19', '351.57', '351.95', '352.33', '352.70', '353.08', '353.46', '353.84', '354.22', '354.60', '354.98', '355.35', '355.73', '356.11', '356.49', '356.87', '357.25', '357.62', '358.00', '358.38', '358.76', '359.14', '359.51', '359.89', '360.27', '360.65', '361.03', '361.40', '361.78', '362.16', '362.54', '362.91', '363.29', '363.67', '364.05', '364.42', '364.80', '365.18', '365.56', '365.93', '366.31', '366.69', '367.07', '367.44', '367.82', '368.20', '368.57', '3
# ...

# %%
for i in dic["data"]:
    plt.plot(i["x"],i["y"],label = i["name"],color = i["line"]["color"])
    plt.xlabel('intensidade(arbitrária)',fontsize = 20)
    plt.ylabel('comprimento de onda(nm)',fontsize = 20)
    plt.legend()
plt.savefig("espectro.png", dpi = 1200)    
plt.show()

# %%
def converte(vetor):
    novo = []
    for i in vetor:
        try:
            novo.append(float(i))
        except:
            print("deu ruim")
            return None
        return novo
